# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
fileaccident = "US_Accidents_May19.csv"
dfaccs = pd.read_csv(fileaccident)
dfaccs.isnull().sum()
len(filedfaccs)
dfaccs.columns
#dfaccs1 = filedfaccs.drop('Source', 'Severity', 'Start_Time', 'End_Time', 'End_Lat', 'End_Lng', axis=1)

dfaccs1 = dfaccs.drop(['Source', 'Severity', 'Description','TMC', 'Start_Time', 'End_Time', 'No_Exit','End_Lat', 'End_Lng', 'Number', 'Roundabout', 'Station', 'Stop'], axis=1)
dfaccs1.head()
# Out:
#     ID  Start_Lat  Start_Lng  Distance(mi)                     Street Side  \
# 0  A-1  39.865147 -84.058723          0.01                     I-70 E    R
# 1  A-2  39.928059 -82.831184          0.01                   Brice Rd    L
# 2  A-3  39.063148 -84.032608          0.01             State Route 32    R
# 3  A-4  39.747753 -84.205582          0.01                     I-75 S    R
# 4  A-5  39.627781 -84.188354          0.01  Miamisburg Centerville Rd    R
#
#            City      County State     Zipcode  ... Give_Way Junction Railway  \
# 0        Dayton  Montgomery    OH       45424  ...    False    False   False
# 1  Reynoldsburg    Franklin    OH  43068-3402  ...    False    False   False
# 2  Williamsburg    Clermont    OH       45176  ...    False    False   False
# 3        Dayton  Montgomery    OH       45417  ...    False    False   False
# 4        Dayton  Montgomery    OH       45459  ...    False    False   False
#
# ...

# %%
dfaccs2 = dfaccs1.drop([ 'Description', 'Wind_Chill(F)','Crossing','Wind_Direction','Precipitation(in)','Railway', 'Amenity','Bump','Traffic_Calming','Give_Way','Junction','Traffic_Signal', 'Turning_Loop'], axis=1)
dfaccs2.head()
# Out:
#     ID  Start_Lat  Start_Lng  Distance(mi)                     Street Side  \
# 0  A-1  39.865147 -84.058723          0.01                     I-70 E    R
# 1  A-2  39.928059 -82.831184          0.01                   Brice Rd    L
# 2  A-3  39.063148 -84.032608          0.01             State Route 32    R
# 3  A-4  39.747753 -84.205582          0.01                     I-75 S    R
# 4  A-5  39.627781 -84.188354          0.01  Miamisburg Centerville Rd    R
#
#            City      County State     Zipcode  ... Temperature(F) Humidity(%)  \
# 0        Dayton  Montgomery    OH       45424  ...           36.9        91.0
# 1  Reynoldsburg    Franklin    OH  43068-3402  ...           37.9       100.0
# 2  Williamsburg    Clermont    OH       45176  ...           36.0       100.0
# 3        Dayton  Montgomery    OH       45417  ...           35.1        96.0
# 4        Dayton  Montgomery    OH       45459  ...           36.0        89.0
#
# ...

# %%
dfaccs3 = dfaccs2.drop([ 'Pressure(in)','ID','Timezone','Civil_Twilight','Country','Wind_Speed(mph)','Visibility(mi)','Weather_Timestamp','Airport_Code', 'Nautical_Twilight','Temperature(F)', 'Humidity(%)','Astronomical_Twilight'], axis=1)
dfaccs3.head()
# Out:
#    Start_Lat  Start_Lng  Distance(mi)                     Street Side  \
# 0  39.865147 -84.058723          0.01                     I-70 E    R
# 1  39.928059 -82.831184          0.01                   Brice Rd    L
# 2  39.063148 -84.032608          0.01             State Route 32    R
# 3  39.747753 -84.205582          0.01                     I-75 S    R
# 4  39.627781 -84.188354          0.01  Miamisburg Centerville Rd    R
#
#            City      County State     Zipcode Weather_Condition Sunrise_Sunset
# 0        Dayton  Montgomery    OH       45424        Light Rain          Night
# 1  Reynoldsburg    Franklin    OH  43068-3402        Light Rain          Night
# 2  Williamsburg    Clermont    OH       45176          Overcast          Night
# 3        Dayton  Montgomery    OH       45417     Mostly Cloudy          Night
# 4        Dayton  Montgomery    OH       45459     Mostly Cloudy            Day

# %%
dfaccs3.to_csv('Accident.csv')
